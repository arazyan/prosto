# %%
import pandas as pd

# %%
df = pd.read_csv('exported.csv')

# %%
df.head()
# Out:
#                         DATE  QUANTITY  NAME  \
# 0  2024-06-16 21:09:38 +0300         1   NaN
# 1  2024-06-16 21:09:34 +0300         1   NaN
# 2  2024-06-16 21:09:32 +0300         1   NaN
# 3  2024-06-16 21:09:27 +0300         1   NaN
# 4  2024-06-16 21:09:23 +0300         1   NaN
#
#                                          CODECONTENT  CODETYPE
# 0  www.xn--90azaccdibh.xn--p1ai/api/form_particip...        15
# 1  https://api.prostospb.team/api/form_participat...        15
# 2  https://api.prostospb.team/api/form_participat...        15
# 3  https://api.prostospb.team/api/form_participat...        15
# 4  xn--90azaccdibh.xn--p1ai/api/form_participatio...        15

# %%
df.columns
# Out:
# Index(['DATE', 'QUANTITY', 'NAME', 'CODECONTENT', 'CODETYPE'], dtype='object')

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df.dtypes
# Out:
# DATE           datetime64[ns, UTC+03:00]
# QUANTITY                           int64
# NAME                             float64
# CODECONTENT                       object
# CODETYPE                           int64
# dtype: object

# %%
df['DATE']
# Out:
# 0     2024-06-16 21:09:38+03:00
# 1     2024-06-16 21:09:34+03:00
# 2     2024-06-16 21:09:32+03:00
# 3     2024-06-16 21:09:27+03:00
# 4     2024-06-16 21:09:23+03:00
#                  ...
# 295   2024-06-16 10:00:53+03:00
# 296   2024-06-16 10:00:45+03:00
# 297   2024-06-16 10:00:40+03:00
# 298   2024-06-16 10:00:30+03:00
# 299   2024-06-16 10:00:20+03:00
# Name: DATE, Length: 300, dtype: datetime64[ns, UTC+03:00]

# %%
t  = [x+'\n' for x in (':'.join(str(t).split(':')[:2]) for t in df['DATE'].dt.time)]
t
# Out:
# ['21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:09\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:08\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:07\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:06\n',
#  '21:05\n',
#  '21:05\n',
#  '21:05\n',
#  '21:05\n',
#  '21:05\n',
#  '21:02\n',
#  '20:16\n',
#  '20:02\n',
#  '19:59\n',
#  '19:57\n',
#  '19:55\n',
#  '19:55\n',
# ...

# %%
with open('time.txt', 'w') as file:
    file.writelines(t)
